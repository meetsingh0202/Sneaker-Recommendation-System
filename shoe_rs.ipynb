# %%
import numpy as np
import pandas as pd

# %%
shoes = pd.read_csv('350Shoes.csv')

# %%
shoes.head()
# Out:
#    shoeId     shoeBrand                                    shoeCategory  \
# 0       1    BEAUTIFEET  Shoes,Women's Shoes,Clothing,All Women's Shoes
# 1       2      Caparros  Shoes,Clothing,Women's Shoes,All Women's Shoes
# 2       3  Vince Camuto  Shoes,Women's Shoes,Clothing,All Women's Shoes
# 3       4  JBU by Jambu  Shoes,Women's Shoes,Clothing,All Women's Shoes
# 4       5   Style & Co.  Shoes,Clothing,Women's Shoes,All Women's Shoes
#
#          shoeColour                                          shoeImage  \
# 0  Multicolor,MULTI  https://i5.walmartimages.com/asr/3990181c-1f37...
# 1            Silver  https://i5.walmartimages.com/asr/a07174df-7c83...
# 2             Brown  https://i5.walmartimages.com/asr/59a1b430-299b...
# 3             Brown  https://i5.walmartimages.com/asr/7bd8cdef-d6aa...
# 4             Beige  https://i5.walmartimages.com/asr/aaf29b0f-1084...
#
#    shoePrice
# 0      10.00
# 1      79.00
# 2     159.00
# 3      69.00
# 4      19.99

# %%
print(shoes.shape)
# Out:
# (348, 6)

# %%
shoes.duplicated().sum()
# Out:
# 0

# %%
shoes
# Out:
#      shoeId         shoeBrand                                    shoeCategory  \
# 0         1        BEAUTIFEET  Shoes,Women's Shoes,Clothing,All Women's Shoes
# 1         2          Caparros  Shoes,Clothing,Women's Shoes,All Women's Shoes
# 2         3      Vince Camuto  Shoes,Women's Shoes,Clothing,All Women's Shoes
# 3         4      JBU by Jambu  Shoes,Women's Shoes,Clothing,All Women's Shoes
# 4         5       Style & Co.  Shoes,Clothing,Women's Shoes,All Women's Shoes
# ..      ...               ...                                             ...
# 343     344  Sebastian Milano  Clothing,Shoes,Women's Shoes,All Women's Shoes
# 344     345        GUPPY LOVE  Shoes,Clothing,Women's Shoes,All Women's Shoes
# 345     346      Kenneth Cole  Shoes,Clothing,Women's Shoes,All Women's Shoes
# 346     347        Extersteps    Women's Sandals,Shoes,Women's Shoes,Clothing
# 347     348           Ipanema                  Women,Sandals,Shoes,Flip-Flops
#
#              shoeColour                                          shoeImage  \
# 0      Multicolor,MULTI  https://i5.walmartimages.com/asr/3990181c-1f37...
# 1                Silver  https://i5.walmartimages.com/asr/a07174df-7c83...
# 2                 Brown  https://i5.walmartimages.com/asr/59a1b430-299b...
# 3                 Brown  https://i5.walmartimages.com/asr/7bd8cdef-d6aa...
# 4                 Beige  https://i5.walmartimages.com/asr/aaf29b0f-1084...
# ..                  ...                                                ...
# 343               Brown  https://i5.walmartimages.com/asr/ee27aa37-10af...
# 344         White,Brown  https://i5.walmartimages.com/asr/b70d9e36-8ced...
# 345  Taupe  Black,Black  https://i5.walmartimages.com/asr/47f917f0-1420...
# 346               Black  http://i5.walmartimages.com/dfw/dce07b8c-f718/...
# 347        Brown,Silver  http://ecx.images-amazon.com/images/I/4150pXeL...
#
#      shoePrice
# 0        10.00
# 1        79.00
# 2       159.00
# 3        69.00
# 4        19.99
# ..         ...
# 343     595.00
# 344      16.96
# 345      64.99
# 346      19.99
# 347      41.25
#
# [348 rows x 6 columns]

# %%
import pickle
from collections import defaultdict 
pickle.dump(shoes, open('shoes.pkl','wb'))
pickle.dump(defaultdict(set), open('userCart.pkl','wb'))

# %%
userCart
# Out:
#    user shoeIds
# 0     1     1,2
