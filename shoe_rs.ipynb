# %%
import numpy as np
import pandas as pd

# %%
shoes = pd.read_csv('ShoesDatabaseFinalCsv.csv')

# %%
shoes.head()
# Out:
#   shoeId   shoeBrand                                    shoeCategory  \
# 0      1  BEAUTIFEET  Shoes,Women's Shoes,Clothing,All Women's Shoes
# 1      2  BEAUTIFEET  Shoes,Women's Shoes,Clothing,All Women's Shoes
# 2      3    Caparros  Shoes,Clothing,Women's Shoes,All Women's Shoes
# 3      4    Caparros  Shoes,Clothing,Women's Shoes,All Women's Shoes
# 4      5    Caparros  Shoes,Clothing,Women's Shoes,All Women's Shoes
#
#          shoeColour                                          shoeImage  \
# 0  Multicolor,MULTI  https://i5.walmartimages.com/asr/3990181c-1f37...
# 1  Multicolor,MULTI  https://i5.walmartimages.com/asr/3990181c-1f37...
# 2            Silver  https://i5.walmartimages.com/asr/a07174df-7c83...
# 3            Silver  https://i5.walmartimages.com/asr/a07174df-7c83...
# 4            Silver  https://i5.walmartimages.com/asr/a07174df-7c83...
#
#    shoePrice
# 0      10.00
# 1       8.00
# 2      79.00
# 3      31.99
# 4       7.99

# %%
print(shoes.shape)
# Out:
# (8475, 6)

# %%
shoes.duplicated().sum()
# Out:
# 2156

# %%
shoes
# Out:
#                     shoeId   shoeBrand  \
# 0                        1  BEAUTIFEET
# 1                        2  BEAUTIFEET
# 2                        3    Caparros
# 3                        4    Caparros
# 4                        5    Caparros
# ...                    ...         ...
# 8470  AVsRmQUrnnc1JgDc36Pe   Unbranded
# 8471  AVsRmQUrnnc1JgDc36Pe   Unbranded
# 8472  AVsRobK8QMlgsOJE61dD  Big Buddha
# 8473  AVsRobNlQMlgsOJE61dE  Big Buddha
# 8474  AVsTXsEoQMlgsOJE69UA  Big Buddha
#
#                                         shoeCategory        shoeColour  \
# 0     Shoes,Women's Shoes,Clothing,All Women's Shoes  Multicolor,MULTI
# 1     Shoes,Women's Shoes,Clothing,All Women's Shoes  Multicolor,MULTI
# 2     Shoes,Clothing,Women's Shoes,All Women's Shoes            Silver
# 3     Shoes,Clothing,Women's Shoes,All Women's Shoes            Silver
# 4     Shoes,Clothing,Women's Shoes,All Women's Shoes            Silver
# ...
