# %%
import numpy as np
import pandas as pd

# %%
shoes = pd.read_csv('ShoeDatabaseFinal.csv')

# %%
shoes.head()
# Out:
#    shoeId     shoeBrand                                    shoeCategory  \
# 0       1      Caparros  Shoes,Clothing,Women's Shoes,All Women's Shoes
# 1       2  Vince Camuto  Shoes,Women's Shoes,Clothing,All Women's Shoes
# 2       3  JBU by Jambu  Shoes,Women's Shoes,Clothing,All Women's Shoes
# 3       4   Style & Co.  Shoes,Clothing,Women's Shoes,All Women's Shoes
# 4       5   Ellen Tracy  Shoes,Clothing,Women's Shoes,All Women's Shoes
#
#   shoeColour                                          shoeImage  shoePrice
# 0     Silver  https://i5.walmartimages.com/asr/a07174df-7c83...      79.00
# 1      Brown  https://i5.walmartimages.com/asr/59a1b430-299b...     159.00
# 2      Brown  https://i5.walmartimages.com/asr/7bd8cdef-d6aa...      69.00
# 3      Beige  https://i5.walmartimages.com/asr/aaf29b0f-1084...      19.99
# 4      Beige  https://i5.walmartimages.com/asr/3dc9c088-f9f0...      21.99

# %%
print(shoes.shape)
# Out:
# (440, 6)

# %%
shoes.duplicated().sum()
# Out:
# 0

# %%
shoes
# Out:
#      shoeId        shoeBrand  \
# 0         1         Caparros
# 1         2     Vince Camuto
# 2         3     JBU by Jambu
# 3         4      Style & Co.
# 4         5      Ellen Tracy
# ..      ...              ...
# 435     436      Barefooters
# 436     437         Grendene
# 437     438     Beacon Shoes
# 438     439  DF by Dearfoams
# 439     440       Big Buddha
#
#                                           shoeCategory  \
# 0       Shoes,Clothing,Women's Shoes,All Women's Shoes
# 1       Shoes,Women's Shoes,Clothing,All Women's Shoes
# 2       Shoes,Women's Shoes,Clothing,All Women's Shoes
# 3       Shoes,Clothing,Women's Shoes,All Women's Shoes
# 4       Shoes,Clothing,Women's Shoes,All Women's Shoes
# ..                                                 ...
# 435     Shoes,Women's Shoes,Clothing,All Women's Shoes
# 436     Clothing,Shoes,Women's Shoes,All Women's Shoes
# 437  Shoes,Slip-ons,Women's Shoes,Clothing,All Wome...
# ...

# %%
import pickle
from collections import defaultdict 
pickle.dump(shoes, open('shoes.pkl','wb'))
pickle.dump(defaultdict(set), open('userCart.pkl','wb'))
