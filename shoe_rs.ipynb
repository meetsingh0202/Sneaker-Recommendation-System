# %%
import numpy as np
import pandas as pd

# %%
shoes = pd.read_csv('ShoeDatabase.csv')

# %%
shoes.head()
# Out:
#    shoeId     shoeBrand                                    shoeCategory  \
# 0       1    BEAUTIFEET  Shoes,Women's Shoes,Clothing,All Women's Shoes
# 1       2      Caparros  Shoes,Clothing,Women's Shoes,All Women's Shoes
# 2       3  Vince Camuto  Shoes,Women's Shoes,Clothing,All Women's Shoes
# 3       4  Michael Kors                             Women's Shoes,Boots
# 4       5   Faded Glory  Shoes,Clothing,Women's Shoes,All Women's Shoes
#
#          shoeColour                                          shoeImage  \
# 0  Multicolor,MULTI  https://i5.walmartimages.com/asr/3990181c-1f37...
# 1            Silver  https://i5.walmartimages.com/asr/a07174df-7c83...
# 2             Brown  https://i5.walmartimages.com/asr/59a1b430-299b...
# 3             Black  http://i.ebayimg.com/images/g/IycAAOSwvUlWshVZ...
# 4          TAN,Grey  http://i5.walmartimages.com/dfw/dce07b8c-e5c0/...
#
#    shoePrice
# 0      10.00
# 1      79.00
# 2     159.00
# 3     180.00
# 4      29.97

# %%
print(shoes.shape)
# Out:
# (672, 6)

# %%
shoes.duplicated().sum()
# Out:
# 0

# %%
shoes
# Out:
#      shoeId        shoeBrand  \
# 0         1       BEAUTIFEET
# 1         2         Caparros
# 2         3     Vince Camuto
# 3         4     Michael Kors
# 4         5      Faded Glory
# ..      ...              ...
# 667     668      Barefooters
# 668     669         Grendene
# 669     670     Beacon Shoes
# 670     671  DF by Dearfoams
# 671     672       Big Buddha
#
#                                           shoeCategory  \
# 0       Shoes,Women's Shoes,Clothing,All Women's Shoes
# 1       Shoes,Clothing,Women's Shoes,All Women's Shoes
# 2       Shoes,Women's Shoes,Clothing,All Women's Shoes
# 3                                  Women's Shoes,Boots
# 4       Shoes,Clothing,Women's Shoes,All Women's Shoes
# ..                                                 ...
# 667     Shoes,Women's Shoes,Clothing,All Women's Shoes
# 668     Clothing,Shoes,Women's Shoes,All Women's Shoes
# 669  Shoes,Slip-ons,Women's Shoes,Clothing,All Wome...
# ...

# %%
import pickle
pickle.dump(shoes, open('shoes.pkl','wb'))
